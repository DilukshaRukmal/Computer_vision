# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %% [markdown]
# Question 1

# %%
img = cv.imread(r'D:\Image processing module\Assignment 1\emma_gray.jpg',cv.IMREAD_COLOR)
assert img is not None

t1 = np.linspace(0,50,50)
t2 = np.linspace(100,255,100)
t3 = np.linspace(150,255,106)
t = np.concatenate((t1,t2,t3),axis= 0).astype(np.uint8)
fig,ax = plt.subplots()
ax.grid()
plt.plot(t)
ax.set_aspect('equal')
assert len(t) == 256
t_img = cv.LUT(img,t)
fig,ax = plt.subplots()
ax.imshow(t_img)
plt.show()

# %% [markdown]
# Question 2(a)

# %%
img = cv.imread(r'D:\Image processing module\Assignment 1\brain_proton_density_slice.png',cv.IMREAD_COLOR)
assert img is not None

t1 = np.linspace(0,128,128)
t2 = np.linspace(128,255,128)
#t3 = np.linspace(150,255,106)
t = np.concatenate((t1,t2),axis= 0).astype(np.uint8)
fig,ax = plt.subplots()
ax.grid()
plt.plot(t)
ax.set_aspect('equal')
assert len(t) == 256
t_img = cv.LUT(img,t)
fig,ax = plt.subplots()
ax.imshow(t_img)
plt.show()

# %% [markdown]
# Question 2(b)

# %%
img = cv.imread(r'D:\Image processing module\Assignment 1\brain_proton_density_slice.png',cv.IMREAD_COLOR)
assert img is not None

t1 = np.linspace(0,0,128)
t2 = np.linspace(255,255,128)
#t3 = np.linspace(150,255,106)
t = np.concatenate((t2,t1),axis= 0).astype(np.uint8)
fig,ax = plt.subplots()
ax.grid()
plt.plot(t)
ax.set_aspect('equal')
assert len(t) == 256
t_img = cv.LUT(img,t)
fig,ax = plt.subplots()
ax.imshow(t_img)
plt.show()
