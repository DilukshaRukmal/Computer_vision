# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %% [markdown]
# Question 1

# %%
img = cv.imread(r'D:\Image processing module\Assignment 1\emma_gray.jpg',cv.IMREAD_COLOR)
assert img is not None

t1 = np.linspace(0,50,50)
t2 = np.linspace(100,255,100)
t3 = np.linspace(150,255,106)
t = np.concatenate((t1,t2,t3),axis= 0).astype(np.uint8)
fig,ax = plt.subplots()
ax.grid()
plt.plot(t)
ax.set_aspect('equal')
assert len(t) == 256
t_img = cv.LUT(img,t)
fig,ax = plt.subplots()
ax.imshow(t_img)
plt.show()

# %% [markdown]
# Question 2(a)

# %%
img = cv.imread(r'D:\Image processing module\Assignment 1\brain_proton_density_slice.png',cv.IMREAD_COLOR)
assert img is not None

t1 = np.linspace(100,100,50)
t2 = np.linspace(50,50,100)
t3 = np.linspace(255,255,106)
t = np.concatenate((t1,t2,t3),axis= 0).astype(np.uint8)
fig,ax = plt.subplots()
ax.grid()
plt.plot(t)
ax.set_aspect('equal')
assert len(t) == 256
t_img = cv.LUT(img,t)
fig,ax = plt.subplots()
ax.imshow(t_img)
plt.show()

# %% [markdown]
# Question 2(b)

# %%
img = cv.imread(r'D:\Image processing module\Assignment 1\brain_proton_density_slice.png',cv.IMREAD_COLOR)
assert img is not None

t1 = np.linspace(0,50,50)
t2 = np.linspace(50,50,100)
t3 = np.linspace(255,255,106)
t = np.concatenate((t2,t1,t3),axis= 0).astype(np.uint8)
fig,ax = plt.subplots()
ax.grid()
plt.plot(t)
ax.set_aspect('equal')
assert len(t) == 256
t_img = cv.LUT(img,t)
fig,ax = plt.subplots()
ax.imshow(t_img)
plt.show()

# %% [markdown]
# Question 3

# %%
img = cv.imread(r'D:\Image processing module\Assignment 1\highlights_and_shadows.jpg',cv.IMREAD_COLOR)
assert img is not None
gamma =0.2

transform = np.array([(i/255.0)**(gamma)*255.0 for i in np.arange(0,256)]).astype('uint8')
t_img = cv.LUT(img,transform)
img_plt = cv.cvtColor(t_img,cv.COLOR_BGR2RGB)
fig,ax = plt.subplots()
ax.imshow(img_plt)
plt.show()
#Original
color=('b','g','r')
for i,c in enumerate(color):
    hist=cv.calcHist([img],[i],None,[256],[0,256])
    plt.plot(hist,color=c)
    plt.xlim([0,256])
    plt.title("Original")
plt.show()

#Gamma corrected
for i,c in enumerate(color):
    hist=cv.calcHist([t_img],[i],None,[256],[0,256])
    plt.plot(hist,color=c)
    plt.xlim([0,256])
    plt.title("Gamma_corected")
plt.show()
