# %% [markdown]
# Name : Rukmal M.A.D
# Index Number : 190531L

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import sympy

# %%
for i in range (1,6):
  print(i,":",i**2)
# Out:
# 1 : 1
# 2 : 4
# 3 : 9
# 4 : 16
# 5 : 25

# %%
for i in range (1,6):
  if not sympy.isprime(i):
    print(i,":",i**2)
  else:
    print(i)
# Out:
# 1 : 1
# 2
# 3
# 4 : 16
# 5

# %%
squares = [i**2 for i in range(1,6)]
for i,val in enumerate(squares):
  print (i+1,":",val)
# Out:
# 1 : 1
# 2 : 4
# 3 : 9
# 4 : 16
# 5 : 25

# %%
squares = [i**2 for i in range(1,6)]
for i,val in enumerate(squares):
    if sympy.isprime(i+1):
        print(i+1)
    else:
        print (i+1,":",val)
# Out:
# 1 : 1
# 2
# 3
# 4 : 16
# 5

# %%
A =np.array([[1,2],[3,4],[5,6]])
B = np.array([[7,8,9,1],[1,2,3,4]])
C =np.matmul(A,B)
print (C)
# Out:
# [[ 9 12 15  9]
#  [25 32 39 19]
#  [41 52 63 29]]

# %%
A = np.array([[1,2],[3,4],[5,6]])
B = np.array([[3,2],[5,4],[3,1]])
print(np.multiply(A,B))
# Out:
# [[ 3  4]
#  [15 16]
#  [15  6]]

# %%
m, c = 2 , -4
N = 10
x = np . linspace (0 , N-1, N) . reshape (N, 1 )
sigma = 10
y = m*x + c + np . random . normal (0 , sigma , (N, 1 ) )
plt.scatter(x,y)

X = np.array(np.ones((N,1)),x,axis=1)
w = linalg.inv(X.T@X)

# %%
img = cv.imread(r'D:\Image processing module\Lecture 1\Images\gal_gaussian.png')
blur = cv.GaussianBlur(img,(5,5),0)
cv.imshow('sample image',blur)
cv.waitKey(0) 
cv.destroyAllWindows()

# %%
img = cv.imread(r'D:\Image processing module\Lecture 1\Images\gal_sandp.png')
median = cv.medianBlur(img,5)
cv.imshow('sample image',median)
cv.waitKey(0) 
cv.destroyAllWindows()
